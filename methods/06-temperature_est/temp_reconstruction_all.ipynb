# %%
import pandas as pd
import geopandas as gpd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
import json
import sys

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import root_mean_squared_error, mean_squared_error, r2_score

from sklearn.model_selection import KFold, ShuffleSplit, RepeatedKFold, train_test_split, ParameterGrid
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import ElasticNetCV, ElasticNet

from joblib import dump, load

from permetrics.regression import RegressionMetric
import os
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
proj_dir = Path('../..')

# %%
geopackage_fn = proj_dir / 'Data/GIS/dams-temp-fish.gpkg'
thorr_packge_dir = proj_dir / "../01-THORR/src/THORR"
# landsat_data_fn = proj_dir / 'Data/landsat/columbia_clean.csv'
landsat_data_fn = proj_dir / 'Data/landsat/crb_landsat.csv'
insitu_data_dir = proj_dir / 'Data/insitu/conditions/processed'
all_data_fn = proj_dir / 'Methods/02-ML_development/input_data/ml_input_data_all.csv'

model_fn = proj_dir / 'Methods/02-ML_development/var1/RFR1.joblib'

# %%
utils = os.path.abspath(thorr_packge_dir/ 'utils')
sys.path.insert(0, utils)

from sql import connect # utility functions for connecting to MySQL

# %%
# Create a connection object to the MySQL database
# conn = connect.Connect(str(proj_dir / "Methods/2.Data/DBManagement/mysql_config.ini"))
conn = connect.Connect(str(proj_dir / ".env/mysql_config.ini"))
connection = conn.conn
cursor = conn.conn.cursor()
# Out:
# Connecting to MySQL database...
# MySQL connection established.

# %%
lsat_data = pd.read_csv(landsat_data_fn, parse_dates=['Date'])
all_data_ = pd.read_csv(all_data_fn, parse_dates=['Date'])
# Out:
# /var/folders/0q/tm370x9d1qdg6nt3w7pcqh_w0000gq/T/ipykernel_10178/494170857.py:2: DtypeWarning: Columns (5,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_data_ = pd.read_csv(all_data_fn, parse_dates=['Date'])

# %%
temp_locs_in_buffer = gpd.read_file(geopackage_fn, layer='TempLocationsInBuffer')

# %%
combined_insitu = pd.DataFrame()

for temp_loc in temp_locs_in_buffer.itertuples():
    insitu_fn = insitu_data_dir / f"{temp_loc.station_ID}.csv"
    if insitu_fn.exists():
        insitu_data = pd.read_csv(insitu_fn, parse_dates=['date'])
        # print(insitu_data.columns)
        # drop utc in date
        insitu_data['date'] = insitu_data['date'].dt.tz_localize(None)

        # keep date and average temperature
        # insitu_data = insitu_data[['date', 'avg_temp(C)', ]]
        # replace -999999 with nan
        # insitu_data.replace(-999999, np.nan, inplace=True)
        insitu_data.dropna(inplace=True)
        insitu_data['station_ID'] = temp_loc.station_ID
        insitu_data['RKm'] = temp_loc.RKm
        insitu_data['Name'] = temp_loc.reach_id
        insitu_data['GNIS_Name'] = temp_loc.GNIS_Name
        combined_insitu = pd.concat([combined_insitu, insitu_data])
        # break

# combined_insitu = pd.concat(combined_insitu)

combined_insitu.rename(columns={'date': 'Date'}, inplace=True)
# combined_insitu = combined_insitu.merge(lsat_data, on='Date', how='left')
# Data/insitu/conditions/processed
combined_insitu
# Out:
#            Date  outflow(m3/d)  inflow(m3/d)  spill(m3/d)  avg_temp(C)  \
# 1945 2004-04-29   4.932288e+07  6.923797e+07          0.0        11.89
# 1946 2004-04-30   4.991006e+07  6.654675e+07          0.0        11.84
# 1947 2004-05-01   4.937181e+07  5.945169e+07          0.0        12.29
# 1948 2004-05-02   4.856444e+07  6.067497e+07          0.0        12.26
# 1949 2004-05-03   5.531698e+07  8.563000e+07          0.0        12.92
# ...         ...            ...           ...          ...          ...
# 484  1998-09-11            NaN           NaN          NaN        20.80
# 485  1998-09-12            NaN           NaN          NaN        20.80
# 486  1998-09-13            NaN           NaN          NaN        20.60
# 487  1998-09-14            NaN           NaN          NaN        20.50
# 488  1998-09-15            NaN           NaN          NaN        20.50
#
#           wse(m)            station_ID  RKm                   Name  \
# 1945  626.245128              DART_ALF  140  Pend_Oreille_River_15
# 1946  626.318280              DART_ALF  140  Pend_Oreille_River_15
# 1947  626.354856              DART_ALF  140  Pend_Oreille_River_15
# 1948  626.364000              DART_ALF  140  Pend_Oreille_River_15
# 1949  626.382288              DART_ALF  140  Pend_Oreille_River_15
# ...          ...                   ...  ...                    ...
# 484          NaN  USGS_460923123235800   60       Columbia_River_7
# 485          NaN  USGS_460923123235800   60       Columbia_River_7
# 486          NaN  USGS_460923123235800   60       Columbia_River_7
# 487          NaN  USGS_460923123235800   60       Columbia_River_7
# 488          NaN  USGS_460923123235800   60       Columbia_River_7
#
#                GNIS_Name  wse_tail(m)  max_temp(C)  min_temp(C)  \
# 1945  Pend Oreille River          NaN          NaN          NaN
# 1946  Pend Oreille River          NaN          NaN          NaN
# 1947  Pend Oreille River          NaN          NaN          NaN
# 1948  Pend Oreille River          NaN          NaN          NaN
# 1949  Pend Oreille River          NaN          NaN          NaN
# ...                  ...          ...          ...          ...
# 484       Columbia River          NaN         20.9         20.7
# 485       Columbia River          NaN         20.9         20.6
# 486       Columbia River          NaN         20.7         20.4
# 487       Columbia River          NaN         20.6         20.4
# 488       Columbia River          NaN         20.7         20.2
#
#       avg discharge (cfs)
# 1945                  NaN
# 1946                  NaN
# 1947                  NaN
# 1948                  NaN
# 1949                  NaN
# ...                   ...
# 484                   NaN
# 485                   NaN
# 486                   NaN
# 487                   NaN
# 488                   NaN
#
# [545190 rows x 14 columns]

# %%
insitu_lsat = pd.merge(
    lsat_data, combined_insitu, on=["Date", "Name", "RKm"], how="outer"
)
nan_fill = -9
insitu_lsat.fillna(nan_fill, inplace=True)
insitu_lsat_clean = insitu_lsat[
    # (insitu_lsat['avg_temp(C)'] >=0) &
    (insitu_lsat["WaterTempC"] >= -40)
    & (insitu_lsat["WaterTempC"] <= 80)
    # & (insitu_lsat["avg_temp(C)"] <= 40)
].copy()
insitu_lsat_clean[["WidthMin", "WidthMean", "WidthMax"]] = insitu_lsat_clean[
    ["WidthMin", "WidthMean", "WidthMax"]
].fillna(15)
insitu_lsat_clean.replace(-9, np.nan, inplace=True)
insitu_lsat_clean["DOY"] = insitu_lsat_clean["Date"].dt.dayofyear

# insitu_lsat_clean.to_csv('ml_inputs_data.csv', index=False)

# %%
col_data = insitu_lsat_clean[insitu_lsat_clean["Name"].str.startswith("Columbia")].dropna(subset=['LandTempC', 'NDVI']).copy()

# %%
rfr = load(model_fn)

# %%
features = [
    "NDVI",
    "LandTempC",
    "ClimateClass",
    "DOY",
    # "WidthMin",
    "WidthMean",
    # "WidthMax",
    # "WaterTempC",
]

# %%
insitu_lsat_clean.replace(nan_fill, np.nan, inplace=True)
insitu_lsat_clean.dropna(subset=['LandTempC', 'NDVI'], inplace=True)
insitu_lsat_clean['est_temp'] = rfr.predict(insitu_lsat_clean[features])

# %%
insitu_lsat_clean.to_csv('reconstructed_data.csv', index=False)

# %%
insitu_lsat_clean.columns
# Out:
# Index(['ReachID', 'Date', 'LandTempC', 'WaterTempC', 'NDVI', 'Mission', 'Name',
#        'ClimateClass', 'RKm', 'WidthMin', 'WidthMean', 'WidthMax',
#        'outflow(m3/d)', 'inflow(m3/d)', 'spill(m3/d)', 'avg_temp(C)', 'wse(m)',
#        'station_ID', 'GNIS_Name', 'wse_tail(m)', 'max_temp(C)', 'min_temp(C)',
#        'avg discharge (cfs)', 'DOY', 'est_temp'],
#       dtype='object')

# %%
insitu_lsat_clean[1000000:]
# Out:
#          ReachID       Date  LandTempC  WaterTempC      NDVI Mission  \
# 1017619    834.0 2014-10-13   20.02050    15.73320  0.127400      L7
# 1017620    834.0 1999-07-25   34.54200    24.15670  0.174452      L7
# 1017621    834.0 1999-07-16   34.94400    23.71910  0.177419      L7
# 1017622    834.0 1999-07-09   35.43330    24.20780  0.201182      L7
# 1017623    834.0 1999-06-30   36.55480    23.21670  0.216862      L7
# ...          ...        ...        ...         ...       ...     ...
# 1290949   1060.0 2022-08-28   18.02820         NaN  0.912089      L9
# 1290950   1060.0 2022-09-06   25.39620         NaN  0.919168      L9
# 1290951   1060.0 2022-10-08   22.69580         NaN  0.901385      L9
# 1290952   1060.0 2022-10-15   23.26610         NaN  0.896315      L9
# 1290953   1060.0 2022-01-09    5.64157     4.31628  0.914922      L9
#
#                    Name  ClimateClass  RKm  WidthMin  ...  avg_temp(C)  \
# 1017619  Snake_River_48           7.0  470      30.0  ...          NaN
# 1017620  Snake_River_48           7.0  470      30.0  ...          NaN
# 1017621  Snake_River_48           7.0  470      30.0  ...          NaN
# 1017622  Snake_River_48           7.0  470      30.0  ...          NaN
# 1017623  Snake_River_48           7.0  470      30.0  ...          NaN
# ...                 ...           ...  ...       ...  ...          ...
# 1290949  Youngs_River_5           9.0   40       NaN  ...          NaN
# 1290950  Youngs_River_5           9.0   40       NaN  ...          NaN
# 1290951  Youngs_River_5           9.0   40       NaN  ...          NaN
# 1290952  Youngs_River_5           9.0   40       NaN  ...          NaN
# 1290953  Youngs_River_5           9.0   40       NaN  ...          NaN
#
#          wse(m)  station_ID  GNIS_Name  wse_tail(m)  max_temp(C)  min_temp(C)  \
# 1017619     NaN         NaN        NaN          NaN          NaN          NaN
# 1017620     NaN         NaN        NaN          NaN          NaN          NaN
# 1017621     NaN         NaN        NaN          NaN          NaN          NaN
# 1017622     NaN         NaN        NaN          NaN          NaN          NaN
# 1017623     NaN         NaN        NaN          NaN          NaN          NaN
# ...         ...         ...        ...          ...          ...          ...
# 1290949     NaN         NaN        NaN          NaN          NaN          NaN
# 1290950     NaN         NaN        NaN          NaN          NaN          NaN
# 1290951     NaN         NaN        NaN          NaN          NaN          NaN
# 1290952     NaN         NaN        NaN          NaN          NaN          NaN
# 1290953     NaN         NaN        NaN          NaN          NaN          NaN
#
#         avg discharge (cfs)  DOY   est_temp
# 1017619                 NaN  286  14.571000
# 1017620                 NaN  206  22.565000
# 1017621                 NaN  197  21.791000
# 1017622                 NaN  190  20.213000
# 1017623                 NaN  181  19.823000
# ...                     ...  ...        ...
# 1290949                 NaN  240  18.606017
# 1290950                 NaN  249  21.054806
# 1290951                 NaN  281  18.446828
# 1290952                 NaN  288  17.254110
# 1290953                 NaN    9   4.735019
#
# [270541 rows x 25 columns]

# %%
# Insert basin data into the table if the entry doesn't already exist
for i, row in insitu_lsat_clean.iterrows():
    if i % 10000 == 0:
        print(f"Processing row {i} of {len(insitu_lsat_clean)}")
    
    query = f"""
    UPDATE `ReachData` 
    SET 
        `EstTempC` = {round(row['est_temp'], 2)}
    WHERE
        (`ReachID` = (SELECT 
        ReachID
    FROM
        Reaches
    WHERE
        Name = '{row['Name']}'))
            AND (`Date` = '{row['Date']}');
    """

    cursor.execute(query)
    conn.conn.commit()

    # # Update the MajorRiverID column if the river exists in the Rivers table
    # query2 = f"""
    # UPDATE Basins
    # SET MajorRiverID = (SELECT RiverID FROM Rivers WHERE Name = '{row['MajorRiver']}')
    # WHERE Name = '{row['Name']}'
    # """

    # cursor.execute(query2)
    # conn.conn.commit()
# Out:
# Processing row 0 of 1270541
# Processing row 10000 of 1270541
# Processing row 20000 of 1270541
# Processing row 30000 of 1270541
# Processing row 40000 of 1270541
# Processing row 50000 of 1270541
# Processing row 60000 of 1270541
# Processing row 70000 of 1270541
# Processing row 80000 of 1270541
# Processing row 90000 of 1270541
# Processing row 100000 of 1270541
# Processing row 110000 of 1270541
# Processing row 120000 of 1270541
# Processing row 130000 of 1270541
# Processing row 140000 of 1270541
# Processing row 150000 of 1270541
# Processing row 160000 of 1270541
# Processing row 170000 of 1270541
# Processing row 180000 of 1270541
# Processing row 190000 of 1270541
# Processing row 200000 of 1270541
# Processing row 210000 of 1270541
# Processing row 220000 of 1270541
# Processing row 230000 of 1270541
# Processing row 240000 of 1270541
# Processing row 250000 of 1270541
# Processing row 260000 of 1270541
# Processing row 270000 of 1270541
# Processing row 280000 of 1270541
# Processing row 290000 of 1270541
# Processing row 300000 of 1270541
# Processing row 310000 of 1270541
# Processing row 320000 of 1270541
# Processing row 330000 of 1270541
# Processing row 340000 of 1270541
# Processing row 350000 of 1270541
# Processing row 360000 of 1270541
# Processing row 370000 of 1270541
# Processing row 380000 of 1270541
# Processing row 390000 of 1270541
# Processing row 400000 of 1270541
# Processing row 410000 of 1270541
# Processing row 420000 of 1270541
# Processing row 430000 of 1270541
# Processing row 440000 of 1270541
# Processing row 450000 of 1270541
# Processing row 460000 of 1270541
# Processing row 470000 of 1270541
# Processing row 480000 of 1270541
# Processing row 490000 of 1270541
# Processing row 500000 of 1270541
# Processing row 510000 of 1270541
# Processing row 520000 of 1270541
# Processing row 530000 of 1270541
# Processing row 540000 of 1270541
# Processing row 550000 of 1270541
# Processing row 560000 of 1270541
# Processing row 570000 of 1270541
# Processing row 580000 of 1270541
# Processing row 590000 of 1270541
# Processing row 600000 of 1270541
# Processing row 610000 of 1270541
# Processing row 620000 of 1270541
# Processing row 630000 of 1270541
# Processing row 640000 of 1270541
# Processing row 650000 of 1270541
# Processing row 660000 of 1270541
# Processing row 670000 of 1270541
# Processing row 680000 of 1270541
# Processing row 690000 of 1270541
# Processing row 700000 of 1270541
# Processing row 710000 of 1270541
# Processing row 720000 of 1270541
# Processing row 730000 of 1270541
# Processing row 740000 of 1270541
# Processing row 750000 of 1270541
# Processing row 760000 of 1270541
# Processing row 770000 of 1270541
# Processing row 780000 of 1270541
# Processing row 790000 of 1270541
# Processing row 810000 of 1270541
# Processing row 820000 of 1270541
# Processing row 830000 of 1270541
# Processing row 840000 of 1270541
# Processing row 850000 of 1270541
# Processing row 860000 of 1270541
# Processing row 870000 of 1270541
# Processing row 880000 of 1270541
# Processing row 890000 of 1270541
# Processing row 900000 of 1270541
# Processing row 910000 of 1270541
# Processing row 920000 of 1270541
# Processing row 930000 of 1270541
# Processing row 940000 of 1270541
# Processing row 950000 of 1270541
# Processing row 960000 of 1270541
# Processing row 970000 of 1270541
# Processing row 980000 of 1270541
# Processing row 990000 of 1270541
# Processing row 1000000 of 1270541
# Processing row 1010000 of 1270541
# Processing row 1020000 of 1270541
# Processing row 1030000 of 1270541
# Processing row 1040000 of 1270541
# Processing row 1050000 of 1270541
# Processing row 1060000 of 1270541
# Processing row 1070000 of 1270541
# Processing row 1080000 of 1270541
# Processing row 1090000 of 1270541
# Processing row 1100000 of 1270541
# Processing row 1110000 of 1270541
# Processing row 1120000 of 1270541
# Processing row 1130000 of 1270541
# Processing row 1140000 of 1270541
# Processing row 1150000 of 1270541
# Processing row 1160000 of 1270541
# Processing row 1170000 of 1270541
# Processing row 1180000 of 1270541
# Processing row 1190000 of 1270541
# Processing row 1200000 of 1270541
# Processing row 1210000 of 1270541
# Processing row 1220000 of 1270541
# Processing row 1230000 of 1270541
# Processing row 1240000 of 1270541
# Processing row 1250000 of 1270541
# Processing row 1260000 of 1270541
# Processing row 1270000 of 1270541
# Processing row 1280000 of 1270541
# Processing row 1290000 of 1270541
