# %%
import pandas as pd
import geopandas as gpd

# %%
reservoirs_gdf = gpd.read_file('/Users/gdarkwah/Library/CloudStorage/OneDrive-UW/01-Research/02-Dams, Temperature and Fish/Data/GIS/dams-temp-fish.gpkg', layer="Reservoirs")
reservoirs_gdf = reservoirs_gdf.to_crs("EPSG:4326")
reaches_gdf = gpd.read_file('/Users/gdarkwah/Library/CloudStorage/OneDrive-UW/01-Research/02-Dams, Temperature and Fish/Data/GIS/dams-temp-fish.gpkg', layer="Reaches")
reaches_gdf = reaches_gdf.to_crs("EPSG:4326")
dams_gdf = gpd.read_file('/Users/gdarkwah/Library/CloudStorage/OneDrive-UW/01-Research/02-Dams, Temperature and Fish/Data/GIS/dams-temp-fish.gpkg', layer="Dams")
dams_gdf = dams_gdf.to_crs("EPSG:4326")
basins_gdf = gpd.read_file('/Users/gdarkwah/Library/CloudStorage/OneDrive-UW/01-Research/02-Dams, Temperature and Fish/Data/GIS/dams-temp-fish.gpkg', layer="Basins")
basins_gdf = basins_gdf.to_crs("EPSG:4326")
rivers_gdf = gpd.read_file('/Users/gdarkwah/Library/CloudStorage/OneDrive-UW/01-Research/02-Dams, Temperature and Fish/Data/GIS/dams-temp-fish.gpkg', layer="Rivers")
rivers_gdf = rivers_gdf.to_crs("EPSG:4326")
buffered_reaches_gdf = gpd.read_file('/Users/gdarkwah/Library/CloudStorage/OneDrive-UW/01-Research/02-Dams, Temperature and Fish/Data/GIS/dams-temp-fish.gpkg', layer="BufferedReaches")
buffered_reaches_gdf = buffered_reaches_gdf.to_crs("EPSG:4326")

# %%
buffered_reaches_gdf
# Out:
#             GNIS_Name           reach_id  RKm  index_right  OBJECTID    ID  \
# 0     Akolkolex River  Akolkolex_River_1    0      16803.0   16804.0   3.0
# 1     Akolkolex River  Akolkolex_River_2   10      16803.0   16804.0   3.0
# 2     Akolkolex River  Akolkolex_River_3   20          NaN       NaN   NaN
# 3     Akolkolex River  Akolkolex_River_4   30          NaN       NaN   NaN
# 4        Beaver River     Beaver_River_1    0      16805.0   16806.0  15.0
# ...               ...                ...  ...          ...       ...   ...
# 1055     Youngs River     Youngs_River_1    0      15371.0   15372.0  10.0
# 1056     Youngs River     Youngs_River_2   10      15371.0   15372.0  10.0
# 1057     Youngs River     Youngs_River_3   20      15371.0   15372.0  10.0
# 1058     Youngs River     Youngs_River_4   30      15371.0   15372.0  10.0
# 1059     Youngs River     Youngs_River_5   40          NaN       NaN   NaN
#
# ...

# %%
reservoirs_gdf.to_file('/Users/gdarkwah/Library/CloudStorage/OneDrive-UW/01-Research/02-Dams, Temperature and Fish/Data/GIS/shapefiles/reservoirs.shp')
reaches_gdf.to_file('/Users/gdarkwah/Library/CloudStorage/OneDrive-UW/01-Research/02-Dams, Temperature and Fish/Data/GIS/shapefiles/reaches.shp')
dams_gdf.to_file('/Users/gdarkwah/Library/CloudStorage/OneDrive-UW/01-Research/02-Dams, Temperature and Fish/Data/GIS/shapefiles/dams.shp')
basins_gdf.to_file('/Users/gdarkwah/Library/CloudStorage/OneDrive-UW/01-Research/02-Dams, Temperature and Fish/Data/GIS/shapefiles/basins.shp')
rivers_gdf.to_file('/Users/gdarkwah/Library/CloudStorage/OneDrive-UW/01-Research/02-Dams, Temperature and Fish/Data/GIS/shapefiles/rivers.shp')
buffered_reaches_gdf.to_file('/Users/gdarkwah/Library/CloudStorage/OneDrive-UW/01-Research/02-Dams, Temperature and Fish/Data/GIS/shapefiles/buffered_reaches.shp')
# Out:
# /var/folders/0q/tm370x9d1qdg6nt3w7pcqh_w0000gq/T/ipykernel_37100/2759600464.py:2: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   reaches_gdf.to_file('/Users/gdarkwah/Library/CloudStorage/OneDrive-UW/01-Research/02-Dams, Temperature and Fish/Data/GIS/shapefiles/reaches.shp')
# /var/folders/0q/tm370x9d1qdg6nt3w7pcqh_w0000gq/T/ipykernel_37100/2759600464.py:6: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   buffered_reaches_gdf.to_file('/Users/gdarkwah/Library/CloudStorage/OneDrive-UW/01-Research/02-Dams, Temperature and Fish/Data/GIS/shapefiles/buffered_reaches.shp')
