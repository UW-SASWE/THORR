# %%
import sys
utils = '/Users/gdarkwah/Library/CloudStorage/OneDrive-UW/01-Research/01-Hydrothermal History/utils'
sys.path.insert(0, utils)

from pathlib import Path
import pandas as pd
import os
from sklearn.preprocessing import StandardScaler, MinMaxScaler

from sql import connect
# from ml import models

import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

# import tensorflow as tf
import HydroErr as he
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
proj_dir = Path("../../..")

# %%
eval_data_2 = pd.read_csv(proj_dir / "Results/2.WaterTempEst/4.Evaluation/eval_data_2.csv")

# %%
variation1 = eval_data_2[eval_data_2['variation'] == 1]
variation2 = eval_data_2[eval_data_2['variation'] == 2]

# %%
# plot kde of the two variations
fig, ax = plt.subplots(figsize=(10, 6))
ax = variation1['rmse_within_50'].plot.kde(label='variation 1')
ax = variation2['rmse_within_50'].plot.kde(label='variation 2')

# %%
import numpy as np
from scipy import stats

stats.ttest_ind(
    list(variation1["rmse_within_50"].to_numpy()),
    list(variation2["rmse_within_50"].to_numpy()),
    # alternative="less",
    equal_var=False,
)
# Out:
# Ttest_indResult(statistic=3.5231717631915074, pvalue=0.0006553650787478935)
