# %% [markdown]
# # Convert a stream's flowline into broken reaches

# %%
# separate environment required for qgis processing
import processing
from qgis.core import QgsApplication
from processing.core.Processing import Processing
from qgis.analysis import QgsNativeAlgorithms
from qgis.core import QgsProperty

from pathlib import Path


qgs = QgsApplication([], False)
qgs.initQgis()
Processing.initialize()
QgsApplication.processingRegistry().addProvider(QgsNativeAlgorithms())
# Out:
# Application path not initialized
# qt.qpa.fonts: Populating font family aliases took 96 ms. Replace uses of missing font family "Open Sans" with one that exists to avoid this cost.
# Logged warning: Duplicate provider native registered
# False

# %%
shapefile_io_dir = Path('/Users/gdarkwah/Library/CloudStorage/OneDrive-UW/01-Research/01-Hydrothermal History/Data/GIS/shapefiles/flowlines_to_reaches')
# shapefile_io_dir = Path('/Users/gdarkwah/Library/CloudStorage/OneDrive-UW/01-Research/01-Hydrothermal History/Data/GIS/shapefiles/flowlines_to_reaches')
# reservoirs_shapefile = Path('/Users/gdarkwah/Library/CloudStorage/OneDrive-UW/01-Research/01-Hydrothermal History/Data/GIS/raw/gee_basin_params/basin_reservoirs.shp')
# reservoirs_shapefile = Path('/Users/gdarkwah/Library/CloudStorage/OneDrive-UW/01-Research/01-Hydrothermal History/Data/GIS/raw/gee_basin_params/basin_reservoirs.shp')
reservoirs_shapefile = Path('/Users/gdarkwah/Library/CloudStorage/OneDrive-UW/01-Research/01-Hydrothermal History/Data/GIS/shapefiles/CRBReservoirs.shp')

input_flowline = shapefile_io_dir / 'columbia_tributaries.shp'
interpolatedPoints = shapefile_io_dir / 'interpolatedPoints.shp'
transects = shapefile_io_dir / 'transects.shp'
reachLines = shapefile_io_dir / 'reachLines.shp'
filteredReachLines = shapefile_io_dir / 'filteredReachLines.shp'
bufferedReaches = shapefile_io_dir / 'bufferedReaches.shp'
finalFilteredReaches = shapefile_io_dir / 'finalFilteredReaches.shp'

temporaryFile = shapefile_io_dir / 'temp.shp'

# bufferDistance = 3000 # meters (half on each side of the line)

# koppen_raster = Path("/Users/gdarkwah/Library/CloudStorage/OneDrive-UW/01-Research/01-Hydrothermal History/Data/GIS/raw/Beck_KG_V1/Beck_KG_V1_present_0p083.tif")
narivs = Path("/Users/gdarkwah/Library/CloudStorage/OneDrive-UW/01-Research/01-Hydrothermal History/Data/GIS/raw/namerica/narivs.shp")
grwl = Path("/Users/gdarkwah/Library/CloudStorage/OneDrive-UW/01-Research/01-Hydrothermal History/Data/GIS/raw/GRWL_summaryStats_V01.01/GRWL_summaryStats.shp")

# %%
def interpolatePoints(input, output, distance=10000, startOffset=0, endOffset=0):
    """
    Interpolate points along a line at a specified distance
    Reference:
        https://docs.qgis.org/3.28/en/docs/user_manual/processing_algs/qgis/vectorgeometry.html#points-along-geometry
        https://gis.stackexchange.com/questions/380361/creating-perpendicular-lines-on-line-using-qgis

    Parameters
    ----------
    input : str or Path object
        Path to the input shapefile
    output : str or Path object
        Path to the output shapefile
    distance : int
        Distance between points
    startOffset : int or float
        Offset from the start of the line
    endOffset : int or float
        Offset from the end of the line

    Returns
    -------
    None
    """
    processing.run(
        "native:pointsalonglines",
        {
            "INPUT": str(input),
            "DISTANCE": distance,
            "START_OFFSET": startOffset,
            "END_OFFSET": endOffset,
            "OUTPUT": str(output),
        },
    )


def createTransects(input, output, transectLength=40):
    """
    Create transects perpendicular to a line
    Reference:
        https://gis.stackexchange.com/questions/380361/creating-perpendicular-lines-on-line-using-qgis

    Parameters
    ----------
    input : str or Path object
        Path to the input shapefile (points along a line)
    output : str or Path object
        Path to the output shapefile
    transectLength : int or float
        Length of the transect

    Returns
    -------
    None
    """
    processing.run(
        "native:geometrybyexpression",
        {
            "INPUT": str(input),
            "OUTPUT_GEOMETRY": 1,
            "WITH_Z": False,
            "WITH_M": False,
            "EXPRESSION": f'extend(\n   make_line(\n      $geometry,\n       project (\n          $geometry, \n          {transectLength}, \n          radians("angle"-90))\n        ),\n   {transectLength},\n   0\n)',
            "OUTPUT": str(output),
        },
    )


def createReachLines(input, splitLine, output):
    """
    Create reach lines from a line and a split line
    Reference:
        https://docs.qgis.org/3.28/en/docs/user_manual/processing_algs/qgis/vectoroverlay.html#split-with-lines
        https://gis.stackexchange.com/questions/380361/creating-perpendicular-lines-on-line-using-qgis

    Parameters
    ----------
    input : str or Path object
        Path to the input shapefile (river flowline)
    splitLine : str or Path object
        Path to the split lines shapefile (transects)
    output : str or Path object
        Path to the output shapefile (reach lines)

    Returns
    -------
    None
    """
    processing.run(
        "native:splitwithlines",
        {
            "INPUT": str(input),
            "LINES": str(splitLine),
            "OUTPUT": str(output),
        },
    )


def joinAttributesByNearest(
    input1,
    input2,
    output,
    # fieldsToCopy=[
    #     "DISCHARGE",
    #     "WIDTH",
    #     "WIDTH5",
    #     "WIDTH95",
    #     "DEPTH",
    #     "DEPTH5",
    #     "DEPTH95",
    # ],
    fieldsToCopy=[
        "width_min_",
        "width_mean",
        "width_max_"
    ],
    max_distance=None,
    neighbors=1,
    discardNonMatching=False,
    prefix="",
):
    """
    Join attributes by nearest
    Reference:
        https://docs.qgis.org/3.28/en/docs/user_manual/processing_algs/qgis/vectoroverlay.html#join-attributes-by-nearest

    Parameters
    ----------
    input1 : str or Path object
        Path to the input shapefile (reach lines)
    input2 : str or Path object
        Path to the input shapefile (shapefile with attributes to join; http://gaia.geosci.unc.edu/rivers/)
    output : str or Path object
        Path to the output shapefile (reach lines with attributes joined)
    fieldsToCopy : list
        List of fields to copy from input2 to input1
    max_distance : int or float
        Maximum distance to search for nearest features
    neighbors : int
        Number of nearest features to search for
    discardNonMatching : bool
        Discard features that do not have a match
    prefix : str
        Prefix to add to the field names of input2

    Returns
    -------
    None
    """
    processing.run(
        "native:joinbynearest",
        {
            "INPUT": str(input1),
            "INPUT_2": str(input2),
            "FIELDS_TO_COPY": fieldsToCopy,
            "DISCARD_NONMATCHING": discardNonMatching,
            "PREFIX": prefix,
            "NEIGHBORS": neighbors,
            "MAX_DISTANCE": max_distance,
            "OUTPUT": str(output),
        },
    )


def aggregateAttributes(input, output, aggregates):
    processing.run(
        "native:aggregate",
        {
            "INPUT": str(input),
            "GROUP_BY": '"uniqueID"',
            "AGGREGATES": aggregates,
            "OUTPUT": str(output),
        },
    )


def fieldCalculator(
    input,
    field_name="uniqueID",
    field_type=1,
    field_length=0,
    field_precision=0,
    formula="@id",
):
    output = Path(input).parents[0] / "temp.shp"

    processing.run(
        "native:fieldcalculator",
        {
            "INPUT": str(input),
            "FIELD_NAME": field_name,
            "FIELD_TYPE": field_type,
            "FIELD_LENGTH": field_length,
            "FIELD_PRECISION": field_precision,
            "FORMULA": formula,
            "OUTPUT": str(output),
        },
    )

    # save features back to the original file
    processing.run(
        "native:savefeatures",
        {
            "INPUT": str(output),
            "OUTPUT": str(input),
            "LAYER_NAME": "",
            "DATASOURCE_OPTIONS": "",
            "LAYER_OPTIONS": "",
        },
    )


def filterReachLines(input, overlay, output):
    """
    Filter reach lines to remove lines that overlap with reservoirs

    Parameters
    ----------
    input : str or Path object
        Path to the input shapefile (reach lines)
    overlay : str or Path object
        Path to the overlay shapefile (reservoirs)
    output : str or Path object
        Path to the output shapefile (filtered reach lines)

    Returns
    -------
    None
    """

    processing.run(
        "native:difference",
        {
            "INPUT": str(input),
            "OVERLAY": str(overlay),
            "OUTPUT": str(output),
            "GRID_SIZE": None,
        },
    )


def createBufferedReaches(input, output, bufferDistance=120):
    """
    Create buffered reaches from a line
    Reference:
        https://docs.qgis.org/3.28/en/docs/user_manual/processing_algs/qgis/vectorgeometry.html#buffer
        https://gis.stackexchange.com/questions/380361/creating-perpendicular-lines-on-line-using-qgis

    Parameters
    ----------
    input : str or Path object
        Path to the input shapefile (reach lines of the river)
    output : str or Path object
        Path to the output shapefile (buffered reaches)
    distance : int or float
        Distance to buffer the reach lines (in meters). Recommendd: the average width of the river.
    """
    processing.run(
        "native:buffer",
        {
            "INPUT": str(input),
            "DISTANCE": QgsProperty.fromExpression(f'"WIDTH" + (2*{bufferDistance})'),
            "SEGMENTS": 5,
            "END_CAP_STYLE": 0,  # Flat ends ()
            "JOIN_STYLE": 0,
            "MITER_LIMIT": 2,
            "DISSOLVE": False,
            "OUTPUT": str(output),
        },
    )


# joinAttributesByNearest(temporaryFile, narivs, reachLines)
def extractReachDimensions(input, dimensionFile, aggregates):
    joinAttributesByNearest(input, dimensionFile, temporaryFile, max_distance=1000)
    aggregateAttributes(temporaryFile, input, aggregates)

# %%
aggregates_narvis = [
    {
        "aggregate": "first_value",
        "delimiter": ",",
        "input": '"GNIS_ID"',
        "length": 10,
        "name": "GNIS_ID",
        "precision": 0,
        "sub_type": 0,
        "type": 10,
        "type_name": "text",
    },
    {
        "aggregate": "first_value",
        "delimiter": ",",
        "input": '"GNIS_Name"',
        "length": 255,
        "name": "GNIS_Name",
        "precision": 0,
        "sub_type": 0,
        "type": 10,
        "type_name": "text",
    },
    {
        "aggregate": "first_value",
        "delimiter": ",",
        "input": '"Basin"',
        "length": 255,
        "name": "Basin",
        "precision": 0,
        "sub_type": 0,
        "type": 10,
        "type_name": "text",
    },
    {
        "aggregate": "first_value",
        "delimiter": ",",
        "input": '"uniqueID"',
        "length": 10,
        "name": "uniqueID",
        "precision": 0,
        "sub_type": 0,
        "type": 4,
        "type_name": "int8",
    },
    {
        "aggregate": "mean",
        "delimiter": ",",
        "input": '"DISCHARGE"',
        "length": 23,
        "name": "DISCHARGE",
        "precision": 15,
        "sub_type": 0,
        "type": 6,
        "type_name": "double precision",
    },
    {
        "aggregate": "mean",
        "delimiter": ",",
        "input": '"WIDTH"',
        "length": 23,
        "name": "WIDTH",
        "precision": 15,
        "sub_type": 0,
        "type": 6,
        "type_name": "double precision",
    },
    {
        "aggregate": "mean",
        "delimiter": ",",
        "input": '"WIDTH5"',
        "length": 23,
        "name": "WIDTH5",
        "precision": 15,
        "sub_type": 0,
        "type": 6,
        "type_name": "double precision",
    },
    {
        "aggregate": "mean",
        "delimiter": ",",
        "input": '"WIDTH95"',
        "length": 23,
        "name": "WIDTH95",
        "precision": 15,
        "sub_type": 0,
        "type": 6,
        "type_name": "double precision",
    },
    {
        "aggregate": "mean",
        "delimiter": ",",
        "input": '"DEPTH"',
        "length": 23,
        "name": "DEPTH",
        "precision": 15,
        "sub_type": 0,
        "type": 6,
        "type_name": "double precision",
    },
    {
        "aggregate": "mean",
        "delimiter": ",",
        "input": '"DEPTH5"',
        "length": 23,
        "name": "DEPTH5",
        "precision": 15,
        "sub_type": 0,
        "type": 6,
        "type_name": "double precision",
    },
    {
        "aggregate": "mean",
        "delimiter": ",",
        "input": '"DEPTH95"',
        "length": 23,
        "name": "DEPTH95",
        "precision": 15,
        "sub_type": 0,
        "type": 6,
        "type_name": "double precision",
    },
    {
        "aggregate": "mean",
        "delimiter": ",",
        "input": '"n"',
        "length": 0,
        "name": "n",
        "precision": 0,
        "sub_type": 0,
        "type": 2,
        "type_name": "integer",
    },
    {
        "aggregate": "mean",
        "delimiter": ",",
        "input": '"distance"',
        "length": 0,
        "name": "distance",
        "precision": 0,
        "sub_type": 0,
        "type": 6,
        "type_name": "double precision",
    },
    {
        "aggregate": "mean",
        "delimiter": ",",
        "input": '"feature_x"',
        "length": 0,
        "name": "feature_x",
        "precision": 0,
        "sub_type": 0,
        "type": 6,
        "type_name": "double precision",
    },
    {
        "aggregate": "mean",
        "delimiter": ",",
        "input": '"feature_y"',
        "length": 0,
        "name": "feature_y",
        "precision": 0,
        "sub_type": 0,
        "type": 6,
        "type_name": "double precision",
    },
    {
        "aggregate": "mean",
        "delimiter": ",",
        "input": '"nearest_x"',
        "length": 0,
        "name": "nearest_x",
        "precision": 0,
        "sub_type": 0,
        "type": 6,
        "type_name": "double precision",
    },
    {
        "aggregate": "mean",
        "delimiter": ",",
        "input": '"nearest_y"',
        "length": 0,
        "name": "nearest_y",
        "precision": 0,
        "sub_type": 0,
        "type": 6,
        "type_name": "double precision",
    },
]

aggregates_grwl = [
    {
        "aggregate": "first_value",
        "delimiter": ",",
        "input": '"GNIS_ID"',
        "length": 10,
        "name": "GNIS_ID",
        "precision": 0,
        "sub_type": 0,
        "type": 10,
        "type_name": "text",
    },
    {
        "aggregate": "first_value",
        "delimiter": ",",
        "input": '"GNIS_Name"',
        "length": 255,
        "name": "GNIS_Name",
        "precision": 0,
        "sub_type": 0,
        "type": 10,
        "type_name": "text",
    },
    {
        "aggregate": "first_value",
        "delimiter": ",",
        "input": '"Basin"',
        "length": 255,
        "name": "Basin",
        "precision": 0,
        "sub_type": 0,
        "type": 10,
        "type_name": "text",
    },
    {
        "aggregate": "first_value",
        "delimiter": ",",
        "input": '"uniqueID"',
        "length": 10,
        "name": "uniqueID",
        "precision": 0,
        "sub_type": 0,
        "type": 4,
        "type_name": "int8",
    },
    {
        "aggregate": "mean",
        "delimiter": ",",
        "input": '"width_min_"',
        "length": 23,
        "name": "WidthMin",
        "precision": 15,
        "sub_type": 0,
        "type": 6,
        "type_name": "double precision",
    },
    {
        "aggregate": "mean",
        "delimiter": ",",
        "input": '"width_mean"',
        "length": 23,
        "name": "WidthMean",
        "precision": 15,
        "sub_type": 0,
        "type": 6,
        "type_name": "double precision",
    },
    {
        "aggregate": "mean",
        "delimiter": ",",
        "input": '"width_max_"',
        "length": 23,
        "name": "WidthMax",
        "precision": 15,
        "sub_type": 0,
        "type": 6,
        "type_name": "double precision",
    },
]

# %%
# test the functions
interpolatePoints(input_flowline, interpolatedPoints)
print("Interpolated points created")
createTransects(interpolatedPoints, transects)
print("Transects created")
createReachLines(input_flowline, transects, reachLines)
print("Reach lines created")
fieldCalculator(reachLines)
print("Unique ID field created")
extractReachDimensions(reachLines, grwl, aggregates_grwl)
print("Reach dimensions extracted")
filterReachLines(reachLines, reservoirs_shapefile, filteredReachLines)
print("Reach lines filtered")
# Out:
# Interpolated points created
# Transects created
# Reach lines created
# Unique ID field created
# Warning 1: Value -13393695.0024622791 of field feature_x of feature 12 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13393695.0024622791 of field nearest_x of feature 12 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12956795.0568334945 of field feature_x of feature 29 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12956795.0568334945 of field nearest_x of feature 29 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13148570.2271600813 of field feature_x of feature 43 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13149190.7226975691 of field nearest_x of feature 43 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13162895.5434855651 of field feature_x of feature 49 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13162973.9184605815 of field nearest_x of feature 49 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13251959.7499042358 of field feature_x of feature 56 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13251959.7499042358 of field nearest_x of feature 56 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13624766.6809347998 of field feature_x of feature 78 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13624772.4062143564 of field nearest_x of feature 78 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13057644.3119537756 of field feature_x of feature 85 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13057615.8777820542 of field nearest_x of feature 85 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13060472.191602299 of field feature_x of feature 86 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13060472.191602299 of field nearest_x of feature 86 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13141107.3580726851 of field feature_x of feature 92 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13141187.5831615385 of field nearest_x of feature 92 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13499260.7610576134 of field feature_x of feature 124 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13499260.7610576134 of field nearest_x of feature 124 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13501362.6597166229 of field feature_x of feature 125 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13501362.6597166229 of field nearest_x of feature 125 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13501188.6391755845 of field feature_x of feature 126 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13501188.6391755845 of field nearest_x of feature 126 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13498533.601209458 of field feature_x of feature 127 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13498533.601209458 of field nearest_x of feature 127 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13495814.8876306936 of field feature_x of feature 128 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13495814.8876306936 of field nearest_x of feature 128 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13493917.7605641931 of field feature_x of feature 129 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13493917.7605641931 of field nearest_x of feature 129 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13488737.5837423727 of field feature_x of feature 130 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13488737.5837423727 of field nearest_x of feature 130 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13481435.8225729894 of field feature_x of feature 131 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13481435.8225729894 of field nearest_x of feature 131 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13474994.6976238489 of field feature_x of feature 132 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13474994.6976238489 of field nearest_x of feature 132 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13477717.5103032421 of field feature_x of feature 133 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13477717.5103032421 of field nearest_x of feature 133 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13478205.4760735482 of field feature_x of feature 134 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13478205.4760735482 of field nearest_x of feature 134 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13476801.4412551019 of field feature_x of feature 135 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13476801.4412551019 of field nearest_x of feature 135 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13479252.7084891051 of field feature_x of feature 136 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13479252.7084891051 of field nearest_x of feature 136 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13482308.1219170988 of field feature_x of feature 137 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13482308.1219170988 of field nearest_x of feature 137 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13484267.5841441266 of field feature_x of feature 138 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13484267.5841441266 of field nearest_x of feature 138 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13481899.0880001802 of field feature_x of feature 139 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13481899.0880001802 of field nearest_x of feature 139 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13478879.343672907 of field feature_x of feature 140 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13478879.343672907 of field nearest_x of feature 140 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13475411.2144172825 of field feature_x of feature 141 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13475411.2144172825 of field nearest_x of feature 141 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13471688.6254150104 of field feature_x of feature 142 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13471688.6254150104 of field nearest_x of feature 142 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13468090.7690462731 of field feature_x of feature 143 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13468090.7690462731 of field nearest_x of feature 143 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13463696.5253191385 of field feature_x of feature 144 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13463696.5253191385 of field nearest_x of feature 144 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13459796.4261113498 of field feature_x of feature 145 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13459796.4261113498 of field nearest_x of feature 145 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13456182.5397741497 of field feature_x of feature 146 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13456182.5397741497 of field nearest_x of feature 146 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13453047.5527005065 of field feature_x of feature 147 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13453047.5527005065 of field nearest_x of feature 147 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13451341.7026526891 of field feature_x of feature 148 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13451341.7026526891 of field nearest_x of feature 148 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13452840.2216661125 of field feature_x of feature 149 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13452840.2216661125 of field nearest_x of feature 149 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13458258.9358167071 of field feature_x of feature 150 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13458258.9358167071 of field nearest_x of feature 150 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13459393.8965732194 of field feature_x of feature 151 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13459389.9222819339 of field nearest_x of feature 151 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13049703.2136389241 of field feature_x of feature 159 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13049717.5706252996 of field nearest_x of feature 159 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12919637.8982417881 of field feature_x of feature 166 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12919637.8982417881 of field nearest_x of feature 166 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12920424.9777330644 of field feature_x of feature 167 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12920424.9777330644 of field nearest_x of feature 167 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12925019.0717395134 of field feature_x of feature 168 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12925019.0717395134 of field nearest_x of feature 168 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12927212.4498079922 of field feature_x of feature 169 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12927166.9479936324 of field nearest_x of feature 169 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12933952.2192257717 of field feature_x of feature 170 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12933952.2192257717 of field nearest_x of feature 170 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12938004.0270918366 of field feature_x of feature 171 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12938004.0270918366 of field nearest_x of feature 171 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12942658.1686206833 of field feature_x of feature 172 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12942658.1686206833 of field nearest_x of feature 172 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12945794.2431810219 of field feature_x of feature 173 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12945794.2431810219 of field nearest_x of feature 173 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12951472.0496433545 of field feature_x of feature 174 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12951472.0496433545 of field nearest_x of feature 174 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12956165.0237033479 of field feature_x of feature 175 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12956165.0237033479 of field nearest_x of feature 175 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12963301.5389255546 of field feature_x of feature 176 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12963301.5389255546 of field nearest_x of feature 176 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12972889.3742594849 of field feature_x of feature 177 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12972889.3742594849 of field nearest_x of feature 177 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12976694.3343166746 of field feature_x of feature 178 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12976694.3343166746 of field nearest_x of feature 178 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12983893.6854687575 of field feature_x of feature 179 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12983893.6854687575 of field nearest_x of feature 179 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12989967.3999176882 of field feature_x of feature 180 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12989967.3999176882 of field nearest_x of feature 180 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13000807.327704601 of field feature_x of feature 181 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13000807.327704601 of field nearest_x of feature 181 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13003114.117526589 of field feature_x of feature 182 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13003114.117526589 of field nearest_x of feature 182 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13010780.9642791376 of field feature_x of feature 183 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13010780.9642791376 of field nearest_x of feature 183 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13013773.0875937883 of field feature_x of feature 184 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13013773.0875937883 of field nearest_x of feature 184 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13016356.6594871972 of field feature_x of feature 185 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13016356.6594871972 of field nearest_x of feature 185 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13022196.6073839534 of field feature_x of feature 186 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13022196.6073839534 of field nearest_x of feature 186 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13023842.9029295538 of field feature_x of feature 187 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13023842.9029295538 of field nearest_x of feature 187 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13027306.8974645901 of field feature_x of feature 188 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13027306.8974645901 of field nearest_x of feature 188 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13030221.1971565932 of field feature_x of feature 189 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13030221.1971565932 of field nearest_x of feature 189 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13034059.1386942007 of field feature_x of feature 190 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13034059.1386942007 of field nearest_x of feature 190 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13037689.6220424343 of field feature_x of feature 191 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13037689.6220424343 of field nearest_x of feature 191 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13046197.7682493441 of field feature_x of feature 192 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13046197.7682493441 of field nearest_x of feature 192 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13050649.6573494617 of field feature_x of feature 193 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13050649.6573494617 of field nearest_x of feature 193 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13058117.4911526404 of field feature_x of feature 194 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13058117.4911526404 of field nearest_x of feature 194 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13068250.6997850426 of field feature_x of feature 195 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13068250.6997850426 of field nearest_x of feature 195 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13072854.5532078091 of field feature_x of feature 196 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13072854.5532078091 of field nearest_x of feature 196 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13078785.5766092744 of field feature_x of feature 197 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13078785.5766092744 of field nearest_x of feature 197 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13083003.8111984245 of field feature_x of feature 198 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13083003.8111984245 of field nearest_x of feature 198 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13087698.1152703166 of field feature_x of feature 199 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13087698.1152703166 of field nearest_x of feature 199 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13095795.9708462954 of field feature_x of feature 200 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13095795.9708462954 of field nearest_x of feature 200 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13101439.2916937079 of field feature_x of feature 201 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13101439.2916937079 of field nearest_x of feature 201 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13111165.7210182436 of field feature_x of feature 202 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13111165.7210182436 of field nearest_x of feature 202 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13121741.6538224779 of field feature_x of feature 203 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13121741.6538224779 of field nearest_x of feature 203 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13121964.8495650217 of field feature_x of feature 204 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13121964.8495650217 of field nearest_x of feature 204 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13135944.4128100947 of field feature_x of feature 205 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13135944.4128100947 of field nearest_x of feature 205 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13139538.1077223159 of field feature_x of feature 206 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13139538.1077223159 of field nearest_x of feature 206 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13145404.53106324 of field feature_x of feature 207 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13145404.53106324 of field nearest_x of feature 207 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13154403.6363311205 of field feature_x of feature 208 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13154411.2903374247 of field nearest_x of feature 208 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13164590.9759740215 of field feature_x of feature 209 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13164590.9759740215 of field nearest_x of feature 209 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13174208.2377803642 of field feature_x of feature 210 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13174208.2377803642 of field nearest_x of feature 210 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13178816.8979052901 of field feature_x of feature 211 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13178816.8979052901 of field nearest_x of feature 211 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13182197.6212854702 of field feature_x of feature 212 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13182197.6212854702 of field nearest_x of feature 212 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13184543.856346488 of field feature_x of feature 213 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13184543.856346488 of field nearest_x of feature 213 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13189570.8964433409 of field feature_x of feature 214 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13189570.8964433409 of field nearest_x of feature 214 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13198872.2501146328 of field feature_x of feature 215 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13198820.2912951205 of field nearest_x of feature 215 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13199182.5761538241 of field feature_x of feature 216 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13199182.5761538241 of field nearest_x of feature 216 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13198794.7754454389 of field feature_x of feature 217 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13198794.7754454389 of field nearest_x of feature 217 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13199264.3339124341 of field feature_x of feature 218 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13199264.3339124341 of field nearest_x of feature 218 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13200223.3247093409 of field feature_x of feature 219 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13200223.3247093409 of field nearest_x of feature 219 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13207394.558510974 of field feature_x of feature 220 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13207394.558510974 of field nearest_x of feature 220 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13210074.2510498799 of field feature_x of feature 221 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13210074.2510498799 of field nearest_x of feature 221 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13210494.1157689542 of field feature_x of feature 222 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13210494.1157689542 of field nearest_x of feature 222 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13208059.1303127706 of field feature_x of feature 223 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13208059.1303127706 of field nearest_x of feature 223 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13205842.879562581 of field feature_x of feature 224 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13205842.879562581 of field nearest_x of feature 224 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13204613.4447644874 of field feature_x of feature 225 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13204613.4447644874 of field nearest_x of feature 225 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13198711.7315662913 of field feature_x of feature 226 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13198711.7315662913 of field nearest_x of feature 226 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13192194.0597744305 of field feature_x of feature 227 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13192194.0597744305 of field nearest_x of feature 227 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13187873.8794843256 of field feature_x of feature 228 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13187848.6422887687 of field nearest_x of feature 228 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13187074.1621260811 of field feature_x of feature 229 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13187074.1621260811 of field nearest_x of feature 229 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13182797.7100750729 of field feature_x of feature 230 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13182797.7100750729 of field nearest_x of feature 230 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13176128.1591399033 of field feature_x of feature 231 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13176128.1591399033 of field nearest_x of feature 231 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13167076.5174765512 of field feature_x of feature 232 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13167076.5174765512 of field nearest_x of feature 232 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13161806.4139755238 of field feature_x of feature 233 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13161806.4139755238 of field nearest_x of feature 233 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13158873.2919907216 of field feature_x of feature 234 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13158852.8295307346 of field nearest_x of feature 234 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13157526.0949304085 of field feature_x of feature 235 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13157504.0623125099 of field nearest_x of feature 235 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13157436.6805684119 of field feature_x of feature 236 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13157407.3417543769 of field nearest_x of feature 236 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13159407.4639347587 of field feature_x of feature 237 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13159407.4639347587 of field nearest_x of feature 237 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13158863.4074700717 of field feature_x of feature 238 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13158863.4074700717 of field nearest_x of feature 238 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13158678.8176776059 of field feature_x of feature 239 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13158691.1819971893 of field nearest_x of feature 239 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13148980.6813885402 of field feature_x of feature 240 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13148980.6813885402 of field nearest_x of feature 240 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13146424.2300714031 of field feature_x of feature 241 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13146424.2300714031 of field nearest_x of feature 241 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13142004.8362332843 of field feature_x of feature 242 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13142004.8362332843 of field nearest_x of feature 242 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13136384.6528968513 of field feature_x of feature 243 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13136384.6528968513 of field nearest_x of feature 243 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13130318.8891421389 of field feature_x of feature 244 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13130318.8891421389 of field nearest_x of feature 244 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13126710.0176168345 of field feature_x of feature 245 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13126710.0176168345 of field nearest_x of feature 245 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13128515.8981194161 of field feature_x of feature 246 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13128515.8981194161 of field nearest_x of feature 246 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13123883.8641532995 of field feature_x of feature 247 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13123883.8641532995 of field nearest_x of feature 247 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13127937.0719750244 of field feature_x of feature 248 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13127937.0719750244 of field nearest_x of feature 248 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13127658.6444363147 of field feature_x of feature 249 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13127658.6444363147 of field nearest_x of feature 249 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13128245.3594964743 of field feature_x of feature 250 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13128245.3594964743 of field nearest_x of feature 250 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13125827.8146990575 of field feature_x of feature 251 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13125827.8146990575 of field nearest_x of feature 251 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13125249.3081489373 of field feature_x of feature 252 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13125249.3081489373 of field nearest_x of feature 252 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13121925.6597229335 of field feature_x of feature 253 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13121925.6597229335 of field nearest_x of feature 253 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13118378.4256861061 of field feature_x of feature 254 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13118378.4256861061 of field nearest_x of feature 254 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13114305.1100140139 of field feature_x of feature 255 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13114288.722736977 of field nearest_x of feature 255 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13118299.9536675829 of field feature_x of feature 256 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13118284.4382442776 of field nearest_x of feature 256 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13122117.3582790699 of field feature_x of feature 257 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13122117.3582790699 of field nearest_x of feature 257 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13127975.3475499842 of field feature_x of feature 258 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13127975.3475499842 of field nearest_x of feature 258 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13124824.3743039984 of field feature_x of feature 259 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13124824.3743039984 of field nearest_x of feature 259 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13132742.3483051211 of field feature_x of feature 260 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13132742.3483051211 of field nearest_x of feature 260 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13135907.6688820403 of field feature_x of feature 261 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13135893.6095092427 of field nearest_x of feature 261 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13143998.5109830461 of field feature_x of feature 262 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13143998.5109830461 of field nearest_x of feature 262 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13146799.2954913769 of field feature_x of feature 263 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13146799.2954913769 of field nearest_x of feature 263 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13146982.4644170422 of field feature_x of feature 264 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13146982.4644170422 of field nearest_x of feature 264 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13150023.8907260541 of field feature_x of feature 265 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13150023.8907260541 of field nearest_x of feature 265 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13151725.1725013256 of field feature_x of feature 266 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13151723.4117419645 of field nearest_x of feature 266 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13152011.8927713782 of field feature_x of feature 267 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13152011.8927713782 of field nearest_x of feature 267 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13151134.5042227302 of field feature_x of feature 268 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13151134.5042227302 of field nearest_x of feature 268 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13149445.95437387 of field feature_x of feature 269 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13149445.95437387 of field nearest_x of feature 269 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13144306.0135656614 of field feature_x of feature 270 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13144306.0135656614 of field nearest_x of feature 270 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13142364.2408450171 of field feature_x of feature 271 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13142364.2408450171 of field nearest_x of feature 271 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13133312.4545775969 of field feature_x of feature 272 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13133312.4545775969 of field nearest_x of feature 272 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13126525.4365726355 of field feature_x of feature 273 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13126525.4365726355 of field nearest_x of feature 273 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13112754.9109424185 of field feature_x of feature 274 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13112754.9109424185 of field nearest_x of feature 274 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13107476.4061326589 of field feature_x of feature 275 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13107476.4061326589 of field nearest_x of feature 275 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13097414.0606587641 of field feature_x of feature 276 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13097414.0606587641 of field nearest_x of feature 276 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13097712.8923109807 of field feature_x of feature 277 not successfully written. Possibly due to too larger number with respect to field width
# ...
# Warning 1: Value -13698992.3928114157 of field nearest_x of feature 759 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13699873.1015316769 of field feature_x of feature 760 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13699873.1015316769 of field nearest_x of feature 760 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13692554.7985006105 of field feature_x of feature 761 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13692554.7985006105 of field nearest_x of feature 761 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13693621.8142891433 of field feature_x of feature 762 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13693621.8142891433 of field nearest_x of feature 762 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13694029.82893553 of field feature_x of feature 763 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13694029.82893553 of field nearest_x of feature 763 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13697452.2913785987 of field feature_x of feature 764 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13697452.2913785987 of field nearest_x of feature 764 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13692252.9421368688 of field feature_x of feature 765 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13692232.284653578 of field nearest_x of feature 765 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13687931.7166238297 of field feature_x of feature 766 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13687931.7166238297 of field nearest_x of feature 766 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13681163.8844802957 of field feature_x of feature 767 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13681163.8844802957 of field nearest_x of feature 767 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13671852.2694016024 of field feature_x of feature 768 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13671852.2694016024 of field nearest_x of feature 768 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13663039.1972800083 of field feature_x of feature 769 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13663039.1972800083 of field nearest_x of feature 769 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13656104.5707354061 of field feature_x of feature 770 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13656104.5707354061 of field nearest_x of feature 770 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13648321.1238731463 of field feature_x of feature 771 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13648321.1238731463 of field nearest_x of feature 771 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13649865.991024429 of field feature_x of feature 772 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13649865.991024429 of field nearest_x of feature 772 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13652835.7327117939 of field feature_x of feature 773 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13652835.7327117939 of field nearest_x of feature 773 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13655530.8017945401 of field feature_x of feature 774 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13655530.8017945401 of field nearest_x of feature 774 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13656623.7559013348 of field feature_x of feature 775 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13656623.7559013348 of field nearest_x of feature 775 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13665961.2034421191 of field feature_x of feature 776 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13665961.2034421191 of field nearest_x of feature 776 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13666027.1639766358 of field feature_x of feature 777 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13665697.7299181316 of field nearest_x of feature 777 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13127459.980080869 of field feature_x of feature 784 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13127459.980080869 of field nearest_x of feature 784 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13046311.9432808161 of field feature_x of feature 790 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13046341.6587430965 of field nearest_x of feature 790 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13643210.4415825941 of field feature_x of feature 807 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13643210.4415825941 of field nearest_x of feature 807 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13648225.803889839 of field feature_x of feature 808 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13648225.803889839 of field nearest_x of feature 808 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13655314.0732807163 of field feature_x of feature 809 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13655314.0732807163 of field nearest_x of feature 809 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13661794.0751005318 of field feature_x of feature 810 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13661794.0751005318 of field nearest_x of feature 810 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13661092.4443407394 of field feature_x of feature 811 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13661092.4443407394 of field nearest_x of feature 811 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13668183.6515512485 of field feature_x of feature 812 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13668183.6515512485 of field nearest_x of feature 812 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13525862.192982655 of field feature_x of feature 829 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13525841.2576235663 of field nearest_x of feature 829 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13071638.2851196788 of field feature_x of feature 841 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13071596.7033456974 of field nearest_x of feature 841 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12953300.2016979717 of field feature_x of feature 849 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12953300.2016979717 of field nearest_x of feature 849 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12962249.4026496969 of field feature_x of feature 850 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12962249.4026496969 of field nearest_x of feature 850 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12968203.0339269601 of field feature_x of feature 851 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12968203.0339269601 of field nearest_x of feature 851 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12974021.4017826244 of field feature_x of feature 852 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12974021.4017826244 of field nearest_x of feature 852 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12978169.5808190163 of field feature_x of feature 853 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12978169.5808190163 of field nearest_x of feature 853 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12978706.2261372134 of field feature_x of feature 854 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12978706.2261372134 of field nearest_x of feature 854 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12977665.552872736 of field feature_x of feature 855 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12977665.552872736 of field nearest_x of feature 855 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12980184.7945042495 of field feature_x of feature 856 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12980184.7945042495 of field nearest_x of feature 856 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12983594.1857009847 of field feature_x of feature 857 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12983594.1857009847 of field nearest_x of feature 857 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12992631.5531290788 of field feature_x of feature 858 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12992631.5531290788 of field nearest_x of feature 858 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12997590.0685596187 of field feature_x of feature 859 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -12997590.0685596187 of field nearest_x of feature 859 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13004268.6259026807 of field feature_x of feature 860 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13004268.6259026807 of field nearest_x of feature 860 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13017322.6013187207 of field feature_x of feature 861 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13017322.6013187207 of field nearest_x of feature 861 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13022898.9866467286 of field feature_x of feature 862 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13022898.9866467286 of field nearest_x of feature 862 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13096655.2255663108 of field feature_x of feature 868 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13095941.6032990478 of field nearest_x of feature 868 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13146129.7991885785 of field feature_x of feature 876 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13146060.482696563 of field nearest_x of feature 876 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13240442.3640226908 of field feature_x of feature 889 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13240442.3640226908 of field nearest_x of feature 889 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13162119.2013579756 of field feature_x of feature 900 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13162015.5804555509 of field nearest_x of feature 900 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13779694.8686695527 of field feature_x of feature 905 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13779694.8686695527 of field nearest_x of feature 905 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13783244.2453152537 of field feature_x of feature 906 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13783244.2453152537 of field nearest_x of feature 906 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13787737.2178527918 of field feature_x of feature 907 not successfully written. Possibly due to too larger number with respect to field width
# Warning 1: Value -13787737.2178527918 of field nearest_x of feature 907 not successfully written. Possibly due to too larger number with respect to field width
# More than 1000 errors or warnings have been reported. No more will be reported from now.
# Reach dimensions extracted
# Reach lines filtered
